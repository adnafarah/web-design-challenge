# %%
#import library
import pandas as pd

# %%
#set the path to the CSV
cities_csv = (r'C:\Users\A454\Desktop\web-design-challenge\resources\cities.csv')

#read the CSV into Pandas
cities_df = pd.read_csv(cities_csv)

# %%
cities_df
# Out:
#             City  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0      Mananjary  -21.2167    48.3333            71.13            77
# 1          Bilma   18.6853    12.9164            96.57            14
# 2      Caravelas  -17.7125   -39.2481            67.68            90
# 3      Martapura   -3.4167   114.8500            82.49            74
# 4    Tuktoyaktuk   69.4541  -133.0374            35.87            96
# ..           ...       ...        ...              ...           ...
# 542     Ramotswa  -24.8716    25.8699            64.02            33
# 543   Navahrudak   53.6000    25.8333            58.69            82
# 544      Ebejico    6.3260   -75.7683            67.62            98
# 545       Cortez   37.3489  -108.5859            65.16            69
# 546      College   64.8569  -147.8028            67.95            73
#
#      Cloudiness (%)  Wind Speed (mph) Country        Date
# 0                56              4.12      MG  1657701742
# ...

# %%
#Capitalise City names
cities_df["City"] = cities_df["City"].str.title()

# %%
#drop unwanted columns
cities_df.drop(["Date"], axis=1, inplace=True)

# %%
cities_df
# Out:
#             City  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0      Mananjary  -21.2167    48.3333            71.13            77
# 1          Bilma   18.6853    12.9164            96.57            14
# 2      Caravelas  -17.7125   -39.2481            67.68            90
# 3      Martapura   -3.4167   114.8500            82.49            74
# 4    Tuktoyaktuk   69.4541  -133.0374            35.87            96
# ..           ...       ...        ...              ...           ...
# 542     Ramotswa  -24.8716    25.8699            64.02            33
# 543   Navahrudak   53.6000    25.8333            58.69            82
# 544      Ebejico    6.3260   -75.7683            67.62            98
# 545       Cortez   37.3489  -108.5859            65.16            69
# 546      College   64.8569  -147.8028            67.95            73
#
#      Cloudiness (%)  Wind Speed (mph) Country
# 0                56              4.12      MG
# ...

# %%
#create a HTML file from the CSV
cities_html = cities_df.to_html("cities.html")
